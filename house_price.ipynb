# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
X=pd.read_csv('train.csv')

# %%
X.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
X.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
X['SalePrice'].value_counts()
# Out:
# 140000    20
# 135000    17
# 145000    14
# 155000    14
# 190000    13
#           ..
# 84900      1
# 424870     1
# 415298     1
# 62383      1
# 34900      1
# Name: SalePrice, Length: 663, dtype: int64

# %%
sns.heatmap(X.corr())

# %%
X.isna().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
X = X.drop(labels='LotFrontage',axis=1)

# %%
X
# Out:
#         Id  MSSubClass MSZoning  LotArea Street Alley LotShape LandContour  \
# 0        1          60       RL     8450   Pave   NaN      Reg         Lvl
# 1        2          20       RL     9600   Pave   NaN      Reg         Lvl
# 2        3          60       RL    11250   Pave   NaN      IR1         Lvl
# 3        4          70       RL     9550   Pave   NaN      IR1         Lvl
# 4        5          60       RL    14260   Pave   NaN      IR1         Lvl
# ...    ...         ...      ...      ...    ...   ...      ...         ...
# 1455  1456          60       RL     7917   Pave   NaN      Reg         Lvl
# 1456  1457          20       RL    13175   Pave   NaN      Reg         Lvl
# 1457  1458          70       RL     9042   Pave   NaN      Reg         Lvl
# 1458  1459          20       RL     9717   Pave   NaN      Reg         Lvl
# 1459  1460          20       RL     9937   Pave   NaN      Reg         Lvl
#
# ...

# %%
X['Fence'].isna().sum()
# Out:
# 1179

# %%
X['Alley'].isna().sum()
# Out:
# 1369

# %%
X['PoolQC'].isna().sum()
# Out:
# 1453

# %%
X['MiscFeature'].isna().sum()
# Out:
# 1406

# %%
X = X.drop(labels='Fence',axis=1)
X = X.drop(labels='Alley',axis=1)
X = X.drop(labels='PoolQC',axis=1)
X = X.drop(labels='MiscFeature',axis=1)
X= X.drop(labels='FireplaceQu',axis=1)

# %%
X
# Out:
#         Id  MSSubClass MSZoning  LotArea Street LotShape LandContour  \
# 0        1          60       RL     8450   Pave      Reg         Lvl
# 1        2          20       RL     9600   Pave      Reg         Lvl
# 2        3          60       RL    11250   Pave      IR1         Lvl
# 3        4          70       RL     9550   Pave      IR1         Lvl
# 4        5          60       RL    14260   Pave      IR1         Lvl
# ...    ...         ...      ...      ...    ...      ...         ...
# 1455  1456          60       RL     7917   Pave      Reg         Lvl
# 1456  1457          20       RL    13175   Pave      Reg         Lvl
# 1457  1458          70       RL     9042   Pave      Reg         Lvl
# 1458  1459          20       RL     9717   Pave      Reg         Lvl
# 1459  1460          20       RL     9937   Pave      Reg         Lvl
#
#      Utilities LotConfig LandSlope  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# ...

# %%
X.iloc[:,60]
# Out:
# 0       TA
# 1       TA
# 2       TA
# 3       TA
# 4       TA
#         ..
# 1455    TA
# 1456    TA
# 1457    TA
# 1458    TA
# 1459    TA
# Name: GarageQual, Length: 1460, dtype: object

# %%
X['GarageQual'].unique()
# Out:
# array(['TA', 'Fa', 'Gd', nan, 'Ex', 'Po'], dtype=object)

# %%
X['GarageQual'].isna().sum()
# Out:
# 81

# %%
X = X.dropna(subset =['BsmtQual','GarageQual','MasVnrType','BsmtExposure','BsmtFinType2','Electrical'])

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder=LabelEncoder()

X.iloc[:,2]= labelencoder.fit_transform(X.iloc[:,2].values)

X.iloc[:,4]= labelencoder.fit_transform(X.iloc[:,4].values)

X.iloc[:,5]= labelencoder.fit_transform(X.iloc[:,5].values)

X.iloc[:,6]= labelencoder.fit_transform(X.iloc[:,6].values)

X.iloc[:,7]= labelencoder.fit_transform(X.iloc[:,7].values)

X.iloc[:,8]= labelencoder.fit_transform(X.iloc[:,8].values)

X.iloc[:,9]= labelencoder.fit_transform(X.iloc[:,9].values)

X.iloc[:,10]= labelencoder.fit_transform(X.iloc[:,10].values)

X.iloc[:,11]= labelencoder.fit_transform(X.iloc[:,11].values)

X.iloc[:,12]= labelencoder.fit_transform(X.iloc[:,12].values)

X.iloc[:,13]= labelencoder.fit_transform(X.iloc[:,13].values)

X.iloc[:,14]= labelencoder.fit_transform(X.iloc[:,14].values)

X.iloc[:,19]= labelencoder.fit_transform(X.iloc[:,19].values)

X.iloc[:,20]= labelencoder.fit_transform(X.iloc[:,20].values)

X.iloc[:,21]= labelencoder.fit_transform(X.iloc[:,21].values)

X.iloc[:,22]= labelencoder.fit_transform(X.iloc[:,22].values)

X.iloc[:,23]= labelencoder.fit_transform(X.iloc[:,23].values)

X.iloc[:,25]= labelencoder.fit_transform(X.iloc[:,25].values)

X.iloc[:,26]= labelencoder.fit_transform(X.iloc[:,26].values)

X.iloc[:,27]= labelencoder.fit_transform(X.iloc[:,27].values)

X.iloc[:,28]= labelencoder.fit_transform(X.iloc[:,28].values)

X.iloc[:,29]= labelencoder.fit_transform(X.iloc[:,29].values)

X.iloc[:,30]= labelencoder.fit_transform(X.iloc[:,30].values)

X.iloc[:,31]= labelencoder.fit_transform(X.iloc[:,31].values)

X.iloc[:,33]= labelencoder.fit_transform(X.iloc[:,33].values)

X.iloc[:,37]= labelencoder.fit_transform(X.iloc[:,37].values)

X.iloc[:,38]= labelencoder.fit_transform(X.iloc[:,38].values)

X.iloc[:,39]= labelencoder.fit_transform(X.iloc[:,39].values)

X.iloc[:,40]= labelencoder.fit_transform(X.iloc[:,40].values)

X.iloc[:,51]= labelencoder.fit_transform(X.iloc[:,51].values)

X.iloc[:,53]= labelencoder.fit_transform(X.iloc[:,53].values)

X.iloc[:,55]= labelencoder.fit_transform(X.iloc[:,55].values)

X.iloc[:,56]= labelencoder.fit_transform(X.iloc[:,56].values)

X.iloc[:,57]= labelencoder.fit_transform(X.iloc[:,57].values)

X.iloc[:,58]= labelencoder.fit_transform(X.iloc[:,58].values)

X.iloc[:,31]= labelencoder.fit_transform(X.iloc[:,31].values)

X.iloc[:,60]= labelencoder.fit_transform(X.iloc[:,60].values)

X.iloc[:,61]= labelencoder.fit_transform(X.iloc[:,61].values)

X.iloc[:,62]= labelencoder.fit_transform(X.iloc[:,62].values)

X.iloc[:,63]= labelencoder.fit_transform(X.iloc[:,63].values)

X.iloc[:,31]= labelencoder.fit_transform(X.iloc[:,31].values)

X.iloc[:,73]= labelencoder.fit_transform(X.iloc[:,73].values)

X.iloc[:,72]= labelencoder.fit_transform(X.iloc[:,74].values)

# %%
X
# Out:
#         Id  MSSubClass  MSZoning  LotArea  Street  LotShape  LandContour  \
# 0        1          60         3     8450       1         3            3
# 1        2          20         3     9600       1         3            3
# 2        3          60         3    11250       1         0            3
# 3        4          70         3     9550       1         0            3
# 4        5          60         3    14260       1         0            3
# ...    ...         ...       ...      ...     ...       ...          ...
# 1455  1456          60         3     7917       1         3            3
# 1456  1457          20         3    13175       1         3            3
# 1457  1458          70         3     9042       1         3            3
# 1458  1459          20         3     9717       1         3            3
# 1459  1460          20         3     9937       1         3            3
#
#       Utilities  LotConfig  LandSlope  ...  EnclosedPorch  3SsnPorch  \
# ...

# %%
x = X.iloc[:, 0:74].values 
Y= X.iloc[:, 74].valuesf

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(x, Y, test_size = 0.2, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test)

# %%
from sklearn.metrics import r2_score
r2_score(Y_test,y_pred)
# Out:
# 0.908689634859142

# %%
regressor.score(X_train,Y_train)
# Out:
# 0.8990983721116381
